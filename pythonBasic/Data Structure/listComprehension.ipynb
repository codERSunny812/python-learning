# %% [markdown]
# #### List comprehension
#
# - its  is a short and fast way to create a list in Python using a single line of code.

# %%
# new_list = [expression for item in iterable]

squares = [x**2 for x in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
newList = [i*i for i in range(20) if i%2 == 0]
newList
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324]
