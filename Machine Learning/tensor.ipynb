# %%
import numpy as np

# %%
arr = np.array(12) # 0-D tensor

# %%
print("0 D tensor",arr)
arr.ndim
# Out:
# 0 D tensor 12
# 0

# %%
# 1 D tensor
arr = np.array([12,34,56,78])
print("1 D tensor",arr)
arr.ndim
# Out:
# 1 D tensor [12 34 56 78]
# 1

# %%
#2 D tensor
arr = np.array([[12,34,56],[78,90,11]])
print("2 D tensor",arr)
arr.ndim
# Out:
# 2 D tensor [[12 34 56]
#  [78 90 11]]
# 2
