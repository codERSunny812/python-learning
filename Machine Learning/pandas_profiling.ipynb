# %%
import pandas_profiling as pd
from pandas_profiling import ProfileReport
import seaborn as sns

# %%
dir(pd)
# Out:
# ['ProfileReport',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compare',
#  'importlib',
#  'pandas_decorator',
#  'spec',
#  'warn',
#  'ydata_profiling']

# %%
flights = sns.load_dataset('flights')

# %%
prof = ProfileReport(flights)

# %%
prof.to_file(output_file="summary.html")
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 63550.06it/s]0:00, 19.66it/s, Describe variable: passengers]
# Summarize dataset: 100%|██████████| 16/16 [00:00<00:00, 18.25it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:00<00:00,  4.42it/s]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.88it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 660.52it/s]
