# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./weight-height.csv')

# %%
df.head(10)
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801
# 5   Male  67.253016  152.212156
# 6   Male  68.785081  183.927889
# 7   Male  68.348516  167.971110
# 8   Male  67.018950  175.929440
# 9   Male  63.456494  156.399676

# %%
df.shape
# Out:
# (10000, 3)

# %%
sns.displot(df["Height"])

# %%
# for outlier detection 
sns.boxplot(df["Height"])
# Out:
# <Axes: ylabel='Height'>

# %%
# define the upper limit percentile 
upper_limit  = df["Height"].quantile(0.95)
upper_limit
# Out:
# np.float64(72.61710606642384)

# %%
# describe the lower limit percentile 

lower_limit = df["Height"].quantile(0.05)
lower_limit
# Out:
# np.float64(60.24622082610544)

# %%
df["Height"].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
new_df = df[(df['Height'] <= upper_limit) & (df['Height'] >= lower_limit)]

# %%
new_df
# Out:
#       Gender     Height      Weight
# 1       Male  68.781904  162.310473
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# 5       Male  67.253016  152.212156
# 6       Male  68.785081  183.927889
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9000 rows x 3 columns]

# %%
new_df["Height"].describe()
# Out:
# count    9000.000000
# mean       66.354968
# std         3.165556
# min        60.246257
# 25%        63.803914
# 50%        66.318070
# 75%        68.902716
# max        72.617038
# Name: Height, dtype: float64

# %%
sns.displot(df["Height"])

# %%
# now checking the outlier

sns.boxplot(new_df["Height"])
# Out:
# <Axes: ylabel='Height'>
