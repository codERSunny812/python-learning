# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
df = load_digits()
X = df.data
y = df.target

# %%
plt.imshow(df.images[0],cmap='pink')
plt.title(f"label:{df.target[0]}")
plt.axis('off')
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)

# %%
print("accuracy_score:",accuracy_score(y_pred,y_test))
# Out:
# accuracy_score: 0.9866666666666667

# %%
print("classifcation repoort",classification_report(y_pred,y_test))
# Out:
# classifcation repoort               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       1.00      0.97      0.99        38
#            2       1.00      1.00      1.00        38
#            3       1.00      0.98      0.99        47
#            4       1.00      0.98      0.99        56
#            5       1.00      0.98      0.99        60
#            6       1.00      1.00      1.00        45
#            7       0.98      1.00      0.99        40
#            8       0.97      0.97      0.97        38
#            9       0.92      0.98      0.95        45
#
#     accuracy                           0.99       450
#    macro avg       0.99      0.99      0.99       450
# weighted avg       0.99      0.99      0.99       450

# %%
idx = 15
predict = knn.predict([X_test[idx]])
predict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 idx = 15
# ----> 2 predict = knn.predict([X_test[idx]])
#       3 predict
#
# NameError: name 'knn' is not defined

# %%
plt.imshow(X_test[idx].reshape(8,8),cmap="gray")
plt.title(f"predicted digit :{predict[0]}")
plt.axis('off')
plt.show()
