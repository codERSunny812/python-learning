# %%
import pandas as pd

# %%
# 1. Load the file 
df = pd.read_csv("./Amazon Sale Report(in).csv")
# Out:
# /var/folders/j6/2w5njgp15332sfj8ybwvwwp40000gn/T/ipykernel_57299/246045872.py:2: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Amazon Sale Report(in).csv")

# %%
# Clean up column names (remove extra spaces)
df.columns = df.columns.str.strip()

# %%
# Keep only rows where Amount is a positive number
df = df[df["Amount"] > 0]

# %%
# Convert Date column to proper date format
df["Date"] = pd.to_datetime(df["Date"])

# %%
print("✅ Data loaded!", len(df), "rows\n")
# Out:
# ✅ Data loaded! 118837 rows

# %%
# ── 2. Total & Average Sales ──────────────────────────────────
print("=" * 45)
print("📊 TOTAL & AVERAGE SALES")
print("=" * 45)
print("Total Sales  : ₹", round(df["Amount"].sum(), 2))
print("Average Sale : ₹", round(df["Amount"].mean(), 2))
print("Total Orders :",   len(df))
# Out:
# ...
# 📊 TOTAL & AVERAGE SALES
# ...
# Total Sales  : ₹ 78592678.3
# Average Sale : ₹ 661.35
# Total Orders : 118837

# %%
# ── 3. Sales by Region (State) ────────────────────────────────
print("\n" + "=" * 45)
print("🗺️  SALES BY STATE (Top 5)")
print("=" * 45)
region = df.groupby("ship-state")["Amount"].sum().sort_values(ascending=False)
print(region)
# print(region.head(5).apply(lambda x: f"₹{x:,.0f}"))
# Out:
# ...
# 🗺️  SALES BY STATE (Top 5)
# ...
# ship-state
# MAHARASHTRA      13335534.14
# KARNATAKA        10481114.37
# TELANGANA         6916615.65
# UTTAR PRADESH     6816642.08
# TAMIL NADU        6515650.11
#                     ...
# Pondicherry           529.00
# rajsthan              521.00
# AR                    493.00
# Rajsthan              443.00
# PB                    399.00
# Name: Amount, Length: 68, dtype: float64

# %%
# ── 4. Monthly Sales & Growth ─────────────────────────────────
print("\n" + "=" * 45)
print("📈 MONTHLY SALES & GROWTH")
print("=" * 45)
df["Month"] = df["Date"].dt.to_period("M")
monthly = df.groupby("Month")["Amount"].sum()
growth  = monthly.pct_change() * 100
for m in monthly.index:
    g = growth[m]
    g_str = f"{g:+.1f}%" if not pd.isna(g) else "  --"
    print(f"  {m}  ₹{monthly[m]:>12,.0f}   Growth: {g_str}")
# Out:
# ...
# 📈 MONTHLY SALES & GROWTH
# ...
#   2022-03  ₹     101,684   Growth:   --
#   2022-04  ₹  28,838,708   Growth: +28261.1%
#   2022-05  ₹  26,226,477   Growth: -9.1%
#   2022-06  ₹  23,425,809   Growth: -10.7%

# %%
# ── 5. Top 5 Products (by Category) ──────────────────────────
print("\n" + "=" * 45)
print("🏆 TOP 5 CATEGORIES")
print("=" * 45)
top_cat = df.groupby("Category")["Amount"].sum().sort_values(ascending=False)
print(top_cat.head(5).apply(lambda x: f"₹{x:,.0f}"))
# Out:
# ...
# 🏆 TOP 5 CATEGORIES
# ...
# Category
# Set              ₹39,204,124
# kurta            ₹21,299,547
# Western Dress    ₹11,216,073
# Top               ₹5,347,792
# Ethnic Dress        ₹791,218
# Name: Amount, dtype: str

# %%
# ── 6. Top 5 SKUs ─────────────────────────────────────────────
print("\n" + "=" * 45)
print("🏆 TOP 5 SKUs (Products)")
print("=" * 45)
top_sku = df.groupby("SKU")["Amount"].sum().sort_values(ascending=False)
print(top_sku.head(5).apply(lambda x: f"₹{x:,.0f}"))
# Out:
# ...
# 🏆 TOP 5 SKUs (Products)
# ...
# SKU
# J0230-SKD-M     ₹527,699
# JNE3797-KR-L    ₹524,582
# J0230-SKD-S     ₹479,937
# JNE3797-KR-M    ₹454,290
# JNE3797-KR-S    ₹407,303
# Name: Amount, dtype: str

# %%
# ── 7. Customer Segmentation (B2B vs B2C) ────────────────────
print("\n" + "=" * 45)
print("👥 B2B vs B2C")
print("=" * 45)
seg = df.groupby("B2B")["Amount"].agg(["sum", "count", "mean"])
seg.index = ["B2C", "B2B"]
seg.columns = ["Total", "Orders", "Avg Order"]
for name, row in seg.iterrows():
    print(f"  {name}  |  Total: ₹{row['Total']:>12,.0f}  |  Orders: {int(row['Orders']):>6,}  |  Avg: ₹{row['Avg Order']:,.0f}")
# Out:
# ...
# 👥 B2B vs B2C
# ...
#   B2C  |  Total: ₹  78,001,458  |  Orders: 117,994  |  Avg: ₹661
#   B2B  |  Total: ₹     591,221  |  Orders:    843  |  Avg: ₹701

# %%
# ── 8. Sales per Customer (Top 5 Order IDs) ──────────────────
print("\n" + "=" * 45)
print("👤 TOP 5 CUSTOMERS (by Order ID)")
print("=" * 45)
cust = df.groupby("Order ID")["Amount"].sum().sort_values(ascending=False)
print(cust.head(5).apply(lambda x: f"₹{x:,.0f}"))
# Out:
# ...
# 👤 TOP 5 CUSTOMERS (by Order ID)
# ...
# Order ID
# 408-3363121-6123562    ₹8,636
# 405-8750647-4224357    ₹8,081
# 403-4288285-8521928    ₹6,993
# 404-9932919-6662730    ₹6,832
# 408-3317403-1729937    ₹6,680
# Name: Amount, dtype: str

# %%
# ── 9. Profitability (Revenue per Unit by Category) ───────────
print("\n" + "=" * 45)
print("💰 REVENUE PER UNIT BY CATEGORY")
print("=" * 45)
profit = df.groupby("Category").agg(Revenue=("Amount","sum"), Units=("Qty","sum"))
profit["Rev_per_Unit"] = profit["Revenue"] / profit["Units"]
profit = profit.sort_values("Rev_per_Unit", ascending=False)
for cat, row in profit.iterrows():
    print(f"  {cat:<20}  ₹{row['Rev_per_Unit']:>7,.0f} / unit")
# Out:
# ...
# 💰 REVENUE PER UNIT BY CATEGORY
# ...
#   Set                   ₹    887 / unit
#   Saree                 ₹    821 / unit
#   Western Dress         ₹    818 / unit
#   Ethnic Dress          ₹    775 / unit
#   Blouse                ₹    558 / unit
#   Top                   ₹    550 / unit
#   kurta                 ₹    483 / unit
#   Bottom                ₹    391 / unit
#   Dupatta               ₹    305 / unit

# %%
# ── 10. Simple Forecast (next 3 months, linear trend) ─────────
print("\n" + "=" * 45)
print("🔮 SALES FORECAST (next 3 months)")
print("=" * 45)
import numpy as np
monthly_vals = monthly.values
x = np.arange(len(monthly_vals))
slope, intercept = np.polyfit(x, monthly_vals, 1)
last_month = monthly.index[-1]
for i in range(1, 4):
    pred = max(slope * (len(monthly_vals) + i - 1) + intercept, 0)
    next_m = last_month + i
    print(f"  {next_m}  →  ₹{pred:>12,.0f}")
# Out:
# ...
# 🔮 SALES FORECAST (next 3 months)
# ...
#   2022-07  →  ₹  36,488,206
#   2022-08  →  ₹  43,224,220
#   2022-09  →  ₹  49,960,235

# %%
# ── 11. Sales by Day of Week ──────────────────────────────────
print("\n" + "=" * 45)
print("📅 SALES BY DAY OF WEEK")
print("=" * 45)
df["Day"] = df["Date"].dt.day_name()
day_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
by_day = df.groupby("Day")["Amount"].sum().reindex(day_order)
for day, val in by_day.items():
    print(f"  {day:<12}  ₹{val:>12,.0f}")
# Out:
# ...
# 📅 SALES BY DAY OF WEEK
# ...
#   Monday        ₹  11,318,441
#   Tuesday       ₹  11,491,626
#   Wednesday     ₹  11,249,823
#   Thursday      ₹  10,358,594
#   Friday        ₹  10,805,395
#   Saturday      ₹  11,339,358
#   Sunday        ₹  12,029,441

# %%
print("\n✅ Done!")
# Out:
# ✅ Done!
