# %%
import numpy as np

# %%
arr = np.random.randint(1,40,20)

# %%
arr
# Out:
# array([27, 34, 26, 13, 38, 38, 24, 12, 18, 38, 13,  5, 38, 35, 17,  1, 39,
#        14, 22, 25])

# %%
#mean 

mean = np.mean(arr)

print("mean of the array is : ", mean)
# Out:
# mean of the array is :  23.85
