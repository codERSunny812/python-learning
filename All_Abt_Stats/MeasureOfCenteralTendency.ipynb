# %%
import numpy as np

# %%
arr = np.random.randint(1,40,20)

# %%
arr
# Out:
# array([ 6, 15, 39, 26, 11, 37, 16,  1,  6, 16, 35, 31, 26, 30,  9, 17,  7,
#        22, 22,  5])

# %%
#mean 

mean = np.mean(arr)

print("mean of the array is : ", mean)
# Out:
# mean of the array is :  18.85

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import scipy.stats as stats
#
# ModuleNotFoundError: No module named 'scipy'
